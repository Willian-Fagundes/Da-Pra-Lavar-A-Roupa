# %%
import requests as r
cep = "06340220"
url = f"https://viacep.com.br/ws/{cep}/json/"

# %%
response = r.get(url)
print(response.json())
# Out:
# {'cep': '06340-220', 'logradouro': 'Rua Rodolfo Camparine', 'complemento': '', 'unidade': '', 'bairro': 'Parque Santa Teresa', 'localidade': 'Carapicuíba', 'uf': 'SP', 'estado': 'São Paulo', 'regiao': 'Sudeste', 'ibge': '3510609', 'gia': '2550', 'ddd': '11', 'siafi': '6313'}

# %%
location = geolocator.geocode("Vila Mariana, SP, Brasil")
latitude, longitude = location.latitude, location.longitude
print(f"Latitude: {location.latitude}, Longitude: {location.longitude}")
# Out:
# Latitude: -23.5837, Longitude: -46.6327408

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=False)
API_KEY = os.getenv("API_KEY")
UNITS = "metric"
URL = "https://api.openweathermap.org/data/2.5/forecast"

response = r.get(URL, params={"lat": {latitude}, "lon" : {longitude}, "appid": API_KEY, "units": UNITS, "lang": "pt_br"})
response.raise_for_status()
raw = response.json()

print(raw)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1780779600, 'main': {'temp': 22.49, 'feels_like': 22.05, 'temp_min': 19.91, 'temp_max': 22.49, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 927, 'humidity': 48, 'temp_kf': 2.58}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01n'}], 'clouds': {'all': 1}, 'wind': {'speed': 1.98, 'deg': 294, 'gust': 4.22}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-06-06 21:00:00'}, {'dt': 1780790400, 'main': {'temp': 19.8, 'feels_like': 19.35, 'temp_min': 17.81, 'temp_max': 19.8, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 928, 'humidity': 58, 'temp_kf': 1.99}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.26, 'deg': 285, 'gust': 1.27}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-06-07 00:00:00'}, {'dt': 1780801200, 'main': {'temp': 14.98, 'feels_like': 14.31, 'temp_min': 14.98, 'temp_max': 14.98, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 928, 'humidity': 68, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 0.9, 'deg': 329, 'gust': 0.85}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-06-07 03:00:00'}, {'dt': 1780812000, 'main': {'temp': 13.4, 'feels_like': 12.65, 'temp_min': 13.4, 'temp_max': 13.4, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 927, 'humidity': 71, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.07, 'deg': 356, 'gust': 1.03}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-06-07 06:00:00'}, {'dt': 1780822800, 'main': {'temp': 12.84, 'feels_like': 12.11, 'temp_min': 12.84, 'temp_max': 12.84, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 927, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'algumas nuvens', 'icon': '02n'}], 'clouds': {'all': 23}, 'wind': {'speed': 1.18, 'deg': 21, 'gust': 1.09}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-06-07 09:00:00'}, {'dt': 1780833600, 'main': {'temp': 18.09, 'feels_like': 17.42, 'temp_min': 18.09, 'temp_max': 18.09, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 928, 'humidity': 56, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'nuvens dispersas', 'icon': '03d'}], 'clouds': {'all': 25}, 'wind': {'speed': 1.19, 'deg': 21, 'gust': 1.38}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-06-07 12:00:00'}, {'dt': 1780844400, 'main': {'temp': 22.27, 'feels_like': 21.47, 'temp_min': 22.27, 'temp_max': 22.27, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 928, 'humidity': 35, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'nuvens dispersas', 'icon': '03d'}], 'clouds': {'all': 25}, 'wind': {'speed': 0.75, 'deg': 249, 'gust': 1.52}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-06-07 15:00:00'}, {'dt': 1780855200, 'main': {'temp': 23.06, 'feels_like': 22.2, 'temp_min': 23.06, 'temp_max': 23.06, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 926, 'humidity': 30, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04d'}], 'clouds': {'all': 53}, 'wind': {'speed': 1.76, 'deg': 235, 'gust': 2.98}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-06-07 18:00:00'}, {'dt': 1780866000, 'main': {'temp': 19.16, 'feels_like': 18.65, 'temp_min': 19.16, 'temp_max': 19.16, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 927, 'humidity': 58, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}], 'clouds': {'all': 66}, 'wind': {'speed': 0.04, 'deg': 346, 'gust': 0.67}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-06-07 21:00:00'}, {'dt': 1780876800, 'mai ...
